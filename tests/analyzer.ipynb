# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/matin/Desktop/Codes/Projects/MarketPulse/data/oxostreetwear_20260808_161908.csv')
df.head()
# Out:
#    post_index                                        description      price  \
# 0           1  ترکیب رنگ جدید سری نارنجی 🍊\n‌\nاورنج لیبل سری...  8000000.0
# 1           2  ⁨ ‌جردن ساق کوتاه مشکی کرم با جزئیات سبز و زیر...  9750000.0
# 2           3  ایرمکس پلاس (TN) سفید با جزئیات سبز\n\nتکنولوژ...  6500000.0
# 3           4  اسنیکری که با الهام گرفتن از دوربین‌های دستی و...  8000000.0
# 4           5  ایرفورس سوپریم [کانسپت]\nمتریال چرم با جزئیات ...  8000000.0
#
#    engagement  comments  views  reactions                         posted_at  \
# 0        2116       NaN   2116          0  2026-04-14T10:40:51.145000+00:00
# 1        3912       NaN   3912          0  2026-04-14T10:41:55.625000+00:00
# 2        5011       NaN   5011          0  2026-04-14T10:42:50.182000+00:00
# 3        7045       NaN   7045          0  2026-04-14T10:43:35.963000+00:00
# 4        8013       NaN   8013          0  2026-04-14T10:44:16.760000+00:00
#
#                        post_url
# ...

# %%
reversed_df = df.iloc[::-1]
reversed_df = reversed_df.reset_index(drop=True)
reversed_df.head(10)
# Out:
#    post_index                                        description       price  \
# 0          70  ایرفورس‌های متفاوت رو از دست نده، از هر کدوم ی...  10000000.0
# 1          69  ایرجردن ساقدار کمیاب!\nبا متریال ساتن و جزئیات...  13000000.0
# 2          68  دانک طوسی با متریال جیر\n\nقابلیت خرید ۴ قسطه ...  10000000.0
# 3          67  VANS 🔥\nپرطرفدارترین سری ونس، Knu Skool\nبا طر...  10000000.0
# 4          66  روز اخر تخفیف رو از دست نده!\n\nبا اسنپ‌پی ۴ ق...         NaN
# 5          65  کمتر از *12 ساعت* تا پایان تخفیف اسنپ‌پی\nاین ...         NaN
# 6          64  ساق بلند‌های فروشگاه رو از دست نده!\n\nبا اسنپ...         NaN
# 7          63  سعی کنید از آخرین روز‌های جشنواره‌ی اسنپ‌پی اس...    500000.0
# 8          62  خوبای اسنپ‌پی تخفیفشون بیشتر شده 🔥\n\nکد تخفیف...    300000.0
# 9          61  سری فیلد نایکی جزو کفش‌های کژوال روزمره حساب م...   7000000.0
#
#    engagement  comments  views  reactions                         posted_at  \
# ...

# %%
avg_price = df['price'].mean()
print(f"The average price is: {avg_price:.2f}")
avg_price_reversed = reversed_df['price'].mean()
print(f"The average price of reversed dataframe is: {avg_price:.2f}")
# Out:
# The average price is: 7445745.11
# The average price of reversed dataframe is: 7445745.11

# %%
cheaper_rows_df = reversed_df[reversed_df['price'] < 200000]
display(cheaper_rows_df.head())
# Out:
#     post_index                                        description     price  \
# 15          55  فروش رفت!\n\nاز تک سایز‌ها یک جفت موجوده، پیشن...  150000.0
# 17          53  مدل‌های تک سایز رو با کد تخفیف اسنپ‌پی سفارش ب...  150000.0
# 44          26  تا قبل از ۱۲ شب مهلت دارید با قیمت قبلی ثبت سف...      20.0
#
#     engagement  comments  views  reactions                         posted_at  \
# 15        4927       NaN   4927          0  2026-05-24T11:36:36.544000+00:00
# 17        5324       NaN   5324          0  2026-05-23T14:54:42.001000+00:00
# 44       12118       NaN  12118          0  2026-05-01T16:45:41.094000+00:00
#
#                         post_url
# 15  https://ble.ir/oxostreetwear
# 17  https://ble.ir/oxostreetwear
# 44  https://ble.ir/oxostreetwear
